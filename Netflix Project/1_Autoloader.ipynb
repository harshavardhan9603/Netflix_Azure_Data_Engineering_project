# %% [markdown]
# #Incremental Data Loading using AutoLoader

# %%
# %sql
CREATE SCHEMA netflix_catalog.net_schema;

# %%
checkpoint_location = "abfss://silver@netflixprojectdl9603.dfs.core.windows.net/checkpoint"

# %%
df = spark.readStream\
  .format("cloudFiles") \
  .option("cloudFiles.format", "csv")\
  .option("cloudFiles.schemaLocation", checkpoint_location)\
  .load("abfss://raw@netflixprojectdl9603.dfs.core.windows.net")

# %%
display(df)

# %%
df.writeStream\
  .format("delta")\
  .option("checkpointLocation", checkpoint_location)\
  .trigger(availableNow=True)\
  .start("abfss://bronze@netflixprojectdl9603.dfs.core.windows.net/netflix_titles")
